# %%
import pandas as pd 
import numpy as no

# %% [markdown]
# ![image.png](attachment:e2e6ed3d-12e6-4c2b-8d79-fa61358eafbe.png)

# %%
students = {"name" : ["Tim Voss", "Nicole Johnson", "Elsa Williams", "John James", "Catherine Jones"], 
            "age" : [19, 20, 21, 20, 23], 
            "favorite_color" : ["red", "yellow", "green", "blue", "green"], "grade" : [91, 95, 82, 75, 93]}

# %%
students_df = pd.DataFrame(students)
